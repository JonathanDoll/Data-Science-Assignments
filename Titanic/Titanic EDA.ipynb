# %%
import pandas as pandas
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pandas.read_csv("train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ##Passenger ID
# ###Continuous or Categorical?
# ID numbers are considered categorical since an ID of 2 does not mean more of or greater than an ID of 1.

# %% [markdown]
# ###Missing Values

# %%
data[data.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There were no missing values for the Passenger ID.

# %% [markdown]
# ##Survived
# ###Continuous or Categorical?

# %% [markdown]
# Survived is categorical.  The 2 options are either 0 for did not survive or 1 for survived.

# %% [markdown]
# ###Missing Values

# %%
data[data.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There were no missing values for the survived column.

# %% [markdown]
# ###Bar Plot

# %%
data.Survived.value_counts().plot(kind="barh")

# %% [markdown]
# As seen in the charts, there were a lot more people who died compared to those who didn't.

# %% [markdown]
# ##Pclass

# %% [markdown]
# ###Categorical or Continuous?

# %% [markdown]
# Pclass is categorical. The options were either 1st (upper), 2nd (middle), or 3rd (lower) class.

# %% [markdown]
# ###Missing Values

# %%
data[data.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There were no missing values for Pclass

# %% [markdown]
# ###Bar Plot

# %%
data.Pclass.value_counts().plot(kind="bar")

# %% [markdown]
# As seen in this bar plot, there were significantly more 3rd class passengers compared to the other 2 classes.

# %% [markdown]
# ##Sex

# %% [markdown]
# ###Categorical or Continuous?

# %% [markdown]
# Sex is categorical. The options were either male or female.

# %% [markdown]
# ###Missing Values

# %%
data[data.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There were no missing values for Sex.

# %% [markdown]
# ###Bar Plot (Since histogram won't work for this)

# %%
data.Sex.value_counts().plot(kind="bar")

# %% [markdown]
# The bar plot shows that there were more males than females.

# %% [markdown]
# ##Age

# %% [markdown]
# ###Categorical or Continuous?

# %% [markdown]
# Age is a continuous. It represents how old the person was.

# %% [markdown]
# ###Missing Values

# %%
data[data.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# There were several (177) missing values for age.

# %% [markdown]
# ###Min, Max, Mean, Standard Deviation

# %%
data.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# dtype: float64

# %% [markdown]
# The minimum age was 0.42 years (5 months) old.

# %% [markdown]
# The maximum age was 80 years old.

# %% [markdown]
# The mean age was 29.7 years old.

# %% [markdown]
# The standard deviation was 14.5 years.

# %% [markdown]
# ###Histogram

# %%
data.Age.hist(bins=8)

# %% [markdown]
# The histogram shows that a large number of passengers were in their 20s and 30s while very few were 60+.

# %% [markdown]
# ##SibSp

# %% [markdown]
# ###Categorical or Continuous?

# %% [markdown]
# SibSp is continuous.  It represents the number of siblings / spouses that passenger has on board.

# %% [markdown]
# ###Missing Values

# %%
data[data.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# The were no missing values for SibSp

# %% [markdown]
# ###Min, Max, Mean, Standard Deviation

# %%
data.SibSp.describe()
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# dtype: float64

# %% [markdown]
# The minimum number of siblings / spouses per passenger onboard was 0

# %% [markdown]
# The maximum number of siblings / spouses per passenger onboard was 6

# %% [markdown]
# The mean number of siblings / spouses per passenger onboard was 0.5

# %% [markdown]
# The standard deviation of siblings / spouses per passenger onboard was 1.1

# %% [markdown]
# ###Histogram

# %%
data.SibSp.hist(bins=8)

# %% [markdown]
# The histogram shows that a majority of the passengers traveled without a sibling or spouse

# %% [markdown]
# ##Parch

# %% [markdown]
# ###Categorical or Continuous?

# %% [markdown]
# Parch is continuous.  It represents the number of parents / children the passenger was traveling with.

# %% [markdown]
# ###Missing Values

# %%
data[data.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There were no missing values for Parch.

# %% [markdown]
# ###Min, Max, Mean, Standard Deviation

# %%
data.Parch.describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# dtype: float64

# %% [markdown]
# The minimum number of parents / children per passenger onboard was 0.

# %% [markdown]
# The maximum number of parents / children per passenger onboard was 6.

# %% [markdown]
# The mean number of parents / children per passenger onboard was 0.4.

# %% [markdown]
# The standard deviation of parents / children per passenger onboard was 0.8.

# %% [markdown]
# ###Histogram

# %%
data.Parch.hist(bins=6)

# %% [markdown]
# The histogram shows that a majority of the passengers traveled without a parent or child.

# %% [markdown]
# ##Ticket

# %% [markdown]
# ###Categorical or Continuous?

# %% [markdown]
# Ticket is categorical.  It is just the ID of the ticket.

# %% [markdown]
# ###Missing Values

# %%
data[data.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# There were no missing values for Ticket.

# %% [markdown]
# ##Fare

# %% [markdown]
# ###Categorical or Continuous?

# %% [markdown]
# Fare is continuous.  It represents the amount paid for a ticket.

# %% [markdown]
# ###Missing Values

# %%
data[data.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# Fare had no missing values.

# %% [markdown]
# ###Min, Max, Mean, Standard Deviation

# %%
data.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# dtype: float64

# %% [markdown]
# The minimum fare was 0

# %% [markdown]
# The maximum fare was 512.3

# %% [markdown]
# The mean fare was 32.2

# %% [markdown]
# The standard deviation of fare was 49.7

# %% [markdown]
# ###Histogram

# %%
data.Fare.hist(bins=5)

# %% [markdown]
# The histogram shows a majority of the passengers had a fare under 100.

# %% [markdown]
# ##Cabin

# %% [markdown]
# ###Categorical or Continuous?

# %% [markdown]
# Cabin is categorical. It represents the cabin the passenger stayed in.

# %% [markdown]
# ###Missing Values

# %%
data[data.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# Cabin had a large amount of values missing. (687)

# %% [markdown]
# ##Embarked

# %% [markdown]
# ###Categorical or Continuous?

# %% [markdown]
# Embarked is categorical. It represents the port of embarkation.  The options were C (Cherbourg), Q (Queenstown), or S (Southampton).

# %% [markdown]
# ###Missing Values

# %%
data[data.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572    80   B28      NaN
# 829  female   62      0      0  113572    80   B28      NaN

# %% [markdown]
# Only 2 passengers had values missing for Embarked.

# %% [markdown]
# ###Bar Plot

# %%
data.Embarked.value_counts().plot(kind="bar")

# %% [markdown]
# The bar plot shows most of the passengers embarked from S (Southampton)
